# %% [markdown]
# # Dogs vs Cats

# %% [markdown]
# https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import vgg16

print(tf.__version__)
print(tf.executing_eagerly())

print('Все устройства:', tf.config.list_physical_devices())
print('GPU:', tf.config.list_physical_devices('GPU'))
# Out:
# 2.20.0
# True
# Все устройства: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# GPU: []

# %% [markdown]
# ## Функции загрузки данных

# %%
import os
from random import shuffle
from glob import glob

IMG_SIZE = (224, 224)  # размер входного изображения сети

BATCH_SIZE = 32

train_files = glob('data/train/*.jpg')
test_files = glob('data/test/*.jpg')

train_files = train_files[:1000]


# загружаем входное изображение и предобрабатываем
def load_image(path, target_size=IMG_SIZE):
    img = cv2.imread(path)[..., ::-1]
    img = cv2.resize(img, target_size)
    return vgg16.preprocess_input(img)  # предобработка для VGG16


# функция-генератор загрузки обучающих данных с диска
def fit_generator(files, batch_size=32):
    batch_size = min(batch_size, len(files))
    while True:
        shuffle(files)
        for k in range(len(files) // batch_size):
            i = k * batch_size
            j = i + batch_size
            if j > len(files):
                j = - j % len(files)
            x = np.array([load_image(path) for path in files[i:j]])
            y = np.array([1. if os.path.basename(path).startswith('dog') else 0.
                          for path in files[i:j]])
            yield (x, y)


# функция-генератор загрузки тестовых изображений с диска
def predict_generator(files):
    while True:
        for path in files:
            x = np.array([load_image(path)])
            yield (x,)

# %% [markdown]
# ## Визуализируем примеры для обучения

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

fig = plt.figure(figsize=(16, 8))
for i, path in enumerate(train_files[:10], 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%s' % path.split('/')[-1])
    img = cv2.imread(path)[..., ::-1]
    img = cv2.resize(img, IMG_SIZE)
    plt.imshow(img)

# %% [markdown]
# ## Загружаем предобученную модель

# %%
# base_model - объект класса keras.models.Model (Functional Model)
base_model = vgg16.VGG16(weights='imagenet',
                         include_top=False,
                         input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Добавляем полносвязный слой

# %%
for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(
    256,
    activation='relu',
    kernel_regularizer=tf.keras.regularizers.l2(1e-4)
)(x)
x = tf.keras.layers.Dropout(0.5)(x)
output = tf.keras.layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.Model(inputs=base_model.input, outputs=output, name='dogs_vs_cats_vgg16')

# %% [markdown]
# ## Выводим архитектуру модели

# %%
model.summary()
# Out:
# Model: "dogs_vs_cats_vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,846,273 (56.63 MB)
#  Trainable params: 131,585 (514.00 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# ## Компилируем модель и запускаем обучение

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

checkpoint_path = 'best_model_vgg16.h5'

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        checkpoint_path,
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=7,
        restore_best_weights=True,
        verbose=1
    )
]

if os.path.exists(checkpoint_path):
    model.load_weights(checkpoint_path)

# %%
val_samples = int(len(train_files) * 0.2)  # число изображений в валидационной выборке

shuffle(train_files)  # перемешиваем обучающую выборку
validation_data = next(fit_generator(train_files[:val_samples], val_samples))
train_data = fit_generator(train_files[val_samples:], BATCH_SIZE)  # данные читаем функцией-генератором

# запускаем процесс обучения
model.fit(train_data,
          steps_per_epoch=10,  # число вызовов генератора за эпоху
          epochs=100,  # число эпох обучения
          validation_data=validation_data)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.5469 - loss: 3.6527 - val_accuracy: 0.6500 - val_loss: 1.1330
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 0.6281 - loss: 2.4521 - val_accuracy: 0.7600 - val_loss: 0.6447
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 0.6906 - loss: 1.4501 - val_accuracy: 0.8800 - val_loss: 0.3028
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.7563 - loss: 1.1113 - val_accuracy: 0.9150 - val_loss: 0.2291
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.7906 - loss: 1.0059 - val_accuracy: 0.9250 - val_loss: 0.1931
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.8281 - loss: 0.7281 - val_accuracy: 0.9350 - val_loss: 0.1732
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.8500 - loss: 0.7506 - val_accuracy: 0.9500 - val_loss: 0.1582
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.8750 - loss: 0.5680 - val_accuracy: 0.9500 - val_loss: 0.1445
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.8719 - loss: 0.5510 - val_accuracy: 0.9600 - val_loss: 0.1406
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9156 - loss: 0.2933 - val_accuracy: 0.9550 - val_loss: 0.1402
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9375 - loss: 0.3646 - val_accuracy: 0.9550 - val_loss: 0.1404
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9125 - loss: 0.3229 - val_accuracy: 0.9700 - val_loss: 0.1242
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9125 - loss: 0.3657 - val_accuracy: 0.9650 - val_loss: 0.1226
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9156 - loss: 0.3626 - val_accuracy: 0.9700 - val_loss: 0.1240
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 0.9344 - loss: 0.3357 - val_accuracy: 0.9650 - val_loss: 0.1199
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9281 - loss: 0.2471 - val_accuracy: 0.9700 - val_loss: 0.1195
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9281 - loss: 0.3238 - val_accuracy: 0.9650 - val_loss: 0.1203
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9344 - loss: 0.3278 - val_accuracy: 0.9650 - val_loss: 0.1183
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9438 - loss: 0.2168 - val_accuracy: 0.9650 - val_loss: 0.1180
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9406 - loss: 0.2516 - val_accuracy: 0.9700 - val_loss: 0.1130
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9281 - loss: 0.2300 - val_accuracy: 0.9650 - val_loss: 0.1180
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9406 - loss: 0.3615 - val_accuracy: 0.9650 - val_loss: 0.1054
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9625 - loss: 0.1387 - val_accuracy: 0.9700 - val_loss: 0.1022
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9594 - loss: 0.2123 - val_accuracy: 0.9650 - val_loss: 0.1011
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9594 - loss: 0.1636 - val_accuracy: 0.9650 - val_loss: 0.0996
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9531 - loss: 0.1535 - val_accuracy: 0.9700 - val_loss: 0.1008
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9656 - loss: 0.1655 - val_accuracy: 0.9650 - val_loss: 0.1067
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9625 - loss: 0.1590 - val_accuracy: 0.9650 - val_loss: 0.1069
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9531 - loss: 0.2137 - val_accuracy: 0.9700 - val_loss: 0.1112
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9406 - loss: 0.2960 - val_accuracy: 0.9650 - val_loss: 0.1062
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9469 - loss: 0.1576 - val_accuracy: 0.9650 - val_loss: 0.1032
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9750 - loss: 0.1175 - val_accuracy: 0.9650 - val_loss: 0.1028
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9688 - loss: 0.1933 - val_accuracy: 0.9700 - val_loss: 0.1000
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9563 - loss: 0.1714 - val_accuracy: 0.9650 - val_loss: 0.0993
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9719 - loss: 0.1167 - val_accuracy: 0.9700 - val_loss: 0.0997
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9656 - loss: 0.1182 - val_accuracy: 0.9650 - val_loss: 0.0999
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9688 - loss: 0.1327 - val_accuracy: 0.9650 - val_loss: 0.1003
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9844 - loss: 0.0994 - val_accuracy: 0.9700 - val_loss: 0.1014
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9781 - loss: 0.0886 - val_accuracy: 0.9700 - val_loss: 0.1007
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9750 - loss: 0.0856 - val_accuracy: 0.9700 - val_loss: 0.0992
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9688 - loss: 0.1904 - val_accuracy: 0.9700 - val_loss: 0.1004
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9719 - loss: 0.1272 - val_accuracy: 0.9700 - val_loss: 0.0985
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.9781 - loss: 0.1219 - val_accuracy: 0.9700 - val_loss: 0.0987
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.9875 - loss: 0.0668 - val_accuracy: 0.9700 - val_loss: 0.1000
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.9719 - loss: 0.1347 - val_accuracy: 0.9700 - val_loss: 0.1027
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 0.9688 - loss: 0.1049 - val_accuracy: 0.9700 - val_loss: 0.1111
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 0.9781 - loss: 0.1196 - val_accuracy: 0.9700 - val_loss: 0.1065
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 0.9781 - loss: 0.1146 - val_accuracy: 0.9750 - val_loss: 0.1044
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9781 - loss: 0.1079 - val_accuracy: 0.9750 - val_loss: 0.1043
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.9844 - loss: 0.0851 - val_accuracy: 0.9700 - val_loss: 0.1074
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9750 - loss: 0.1059 - val_accuracy: 0.9650 - val_loss: 0.1031
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9812 - loss: 0.0855 - val_accuracy: 0.9600 - val_loss: 0.1027
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9812 - loss: 0.1054 - val_accuracy: 0.9650 - val_loss: 0.0995
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9812 - loss: 0.0770 - val_accuracy: 0.9650 - val_loss: 0.0996
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9719 - loss: 0.0766 - val_accuracy: 0.9650 - val_loss: 0.1000
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9781 - loss: 0.1228 - val_accuracy: 0.9700 - val_loss: 0.1025
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9906 - loss: 0.0465 - val_accuracy: 0.9650 - val_loss: 0.1022
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9875 - loss: 0.0741 - val_accuracy: 0.9650 - val_loss: 0.1025
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9781 - loss: 0.1054 - val_accuracy: 0.9650 - val_loss: 0.1071
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9844 - loss: 0.0753 - val_accuracy: 0.9700 - val_loss: 0.1067
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9906 - loss: 0.0697 - val_accuracy: 0.9650 - val_loss: 0.1078
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9844 - loss: 0.0815 - val_accuracy: 0.9650 - val_loss: 0.1072
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9812 - loss: 0.0872 - val_accuracy: 0.9600 - val_loss: 0.1125
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9906 - loss: 0.0528 - val_accuracy: 0.9650 - val_loss: 0.1181
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9781 - loss: 0.0760 - val_accuracy: 0.9650 - val_loss: 0.1172
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9906 - loss: 0.0644 - val_accuracy: 0.9650 - val_loss: 0.1152
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9937 - loss: 0.0613 - val_accuracy: 0.9600 - val_loss: 0.1130
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9937 - loss: 0.0613 - val_accuracy: 0.9600 - val_loss: 0.1107
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9688 - loss: 0.1027 - val_accuracy: 0.9650 - val_loss: 0.1100
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9844 - loss: 0.0677 - val_accuracy: 0.9650 - val_loss: 0.1088
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9875 - loss: 0.0598 - val_accuracy: 0.9600 - val_loss: 0.1072
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9875 - loss: 0.0703 - val_accuracy: 0.9650 - val_loss: 0.1061
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9969 - loss: 0.0449 - val_accuracy: 0.9650 - val_loss: 0.1055
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 0.9875 - loss: 0.0667 - val_accuracy: 0.9650 - val_loss: 0.1043
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 0.9875 - loss: 0.0752 - val_accuracy: 0.9600 - val_loss: 0.1037
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 0.9781 - loss: 0.0883 - val_accuracy: 0.9600 - val_loss: 0.1066
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9906 - loss: 0.0627 - val_accuracy: 0.9600 - val_loss: 0.1084
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 1.0000 - loss: 0.0380 - val_accuracy: 0.9600 - val_loss: 0.1091
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9906 - loss: 0.0549 - val_accuracy: 0.9650 - val_loss: 0.1102
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9844 - loss: 0.0557 - val_accuracy: 0.9650 - val_loss: 0.1131
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9969 - loss: 0.0622 - val_accuracy: 0.9700 - val_loss: 0.1240
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.9875 - loss: 0.0583 - val_accuracy: 0.9700 - val_loss: 0.1236
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9875 - loss: 0.0649 - val_accuracy: 0.9650 - val_loss: 0.1110
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9781 - loss: 0.0763 - val_accuracy: 0.9650 - val_loss: 0.1084
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9875 - loss: 0.0657 - val_accuracy: 0.9650 - val_loss: 0.1092
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9781 - loss: 0.0790 - val_accuracy: 0.9700 - val_loss: 0.1026
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9906 - loss: 0.0561 - val_accuracy: 0.9700 - val_loss: 0.1031
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.9781 - loss: 0.0704 - val_accuracy: 0.9700 - val_loss: 0.0993
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 0.9875 - loss: 0.0563 - val_accuracy: 0.9650 - val_loss: 0.0985
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.9937 - loss: 0.0502 - val_accuracy: 0.9650 - val_loss: 0.0979
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.9750 - loss: 0.0783 - val_accuracy: 0.9650 - val_loss: 0.0967
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 0.9937 - loss: 0.0464 - val_accuracy: 0.9650 - val_loss: 0.0950
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.9875 - loss: 0.0561 - val_accuracy: 0.9700 - val_loss: 0.0959
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 1.0000 - loss: 0.0366 - val_accuracy: 0.9700 - val_loss: 0.0968
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 0.9875 - loss: 0.0619 - val_accuracy: 0.9700 - val_loss: 0.0991
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 1.0000 - loss: 0.0381 - val_accuracy: 0.9700 - val_loss: 0.1009
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 0.9906 - loss: 0.0508 - val_accuracy: 0.9700 - val_loss: 0.1027
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 0.9937 - loss: 0.0466 - val_accuracy: 0.9700 - val_loss: 0.1025
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9937 - loss: 0.0515 - val_accuracy: 0.9700 - val_loss: 0.1047
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/step - accuracy: 0.9875 - loss: 0.0591 - val_accuracy: 0.9700 - val_loss: 0.1069

# %%
model.save('cats-dogs-vgg16.keras')

# %% [markdown]
# ## Предсказания на проверочной выборке

# %%
test_pred = model.predict(
    predict_generator(test_files),
    steps=len(test_files),
    verbose=1
)
# Out:
# 12500/12500 ━━━━━━━━━━━━━━━━━━━━ 772s 62ms/step

# %%
fig = plt.figure(figsize=(16, 8))
for i, (path, score) in enumerate(zip(test_files[:10], test_pred[:10]), 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title(f'{score.item():.2f} {os.path.basename(path)}')
    img = cv2.imread(path)[..., ::-1]
    img = cv2.resize(img, IMG_SIZE)
    subplot.imshow(img)

# %% [markdown]
# ## Готовим данные для отправки

# %%
import re
import pandas as pd

ids = []
labels = []

for path, score in zip(test_files, test_pred):
    img_id = int(re.search(r'(\d+)\.jpg$', path).group(1))
    ids.append(img_id)
    labels.append(score.item())

submission = pd.DataFrame({'id': ids, 'label': labels})
submission = submission.sort_values('id')

submission.to_csv('submission.csv', index=False)
